# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiprasannabollam/AI-assistant-coding/blob/main/AI_lab4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Zero-Shot Prompting – Leap Year Check

# %%
def is_leap_year(year):
    if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
        return True
    else:
        return False

# %% [markdown]
# # Task 2: One-Shot Prompting – Centimeters to Inches Conversion

# %%
def cm_to_inches(cm):
    return round(cm / 2.54, 2)

# %% [markdown]
# # Task 3: Few-Shot Prompting – Name Formatting

# %%
def format_name(full_name):
    first, last = full_name.split()
    return f"{last}, {first}"

# %% [markdown]
# # Task 4: Comparative Analysis – Zero-Shot vs Few-Shot

# %%
def count_vowels(text):
    count = 0
    for ch in text:
        if ch.lower() in 'aeiou':
            count += 1
    return count

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"
    return sum(1 for char in text if char in vowels)

# %% [markdown]
# # Task 5: Few-Shot Prompting – File Handling

# %%
def count_lines(filename):
    with open(filename, 'r') as file:
        return len(file.readlines())
